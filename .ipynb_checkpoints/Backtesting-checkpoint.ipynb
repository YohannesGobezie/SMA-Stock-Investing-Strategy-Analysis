# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Telus = yf.download("T", start="2010-01-01", end="2023-07-14")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Telus
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2010-01-04  21.457705  21.608761  21.359516  21.586103   7.714362  38576858
# 2010-01-05  21.676737  21.699396  21.412388  21.480364   7.676573  46650478
# 2010-01-06  21.110271  21.170694  20.808157  20.853474   7.601161  50172450
# 2010-01-07  20.830816  20.913897  20.483383  20.619335   7.515818  44486797
# 2010-01-08  20.611782  20.687311  20.302114  20.468279   7.460754  36586622
# ...               ...        ...        ...        ...        ...       ...
# 2023-07-07  15.540000  15.750000  15.530000  15.610000  15.610000  28987000
# 2023-07-10  15.520000  15.550000  15.220000  15.270000  15.270000  45305500
# 2023-07-11  15.290000  15.350000  15.110000  15.230000  15.230000  39688000
# 2023-07-12  15.240000  15.270000  15.100000  15.120000  15.120000  46478300
# 2023-07-13  15.140000  15.170000  15.010000  15.120000  15.120000  40508200
#
# [3404 rows x 6 columns]

# %%
ff_tickers = ["MCD", "WEN", "CMG", "DPZ", "SBUX", "PZZA", "WING", "SHAK", "YUM"]
tech_tickers = ["AAPL", "TSLA", "MSFT", "AMD", "GME", "AMC", "NVDA", "GOOG", "AMZN", "INTC", "META", "BABA", "EA", "PYPL", "CRM", "YELP", "ZG", "MTCH", "ORCL"]
tech = yf.download(tech_tickers, start="2010-01-01", end="2023-07-14")
ff = yf.download(ff_tickers, start="2010-01-01", end="2023-07-14")
# Out:
# [*********************100%***********************]  19 of 19 completed
# [*********************100%***********************]  9 of 9 completed

# %%
ff
tech
# Out:
#              Adj Close                                                       \
#                   AAPL   AMC         AMD        AMZN       BABA         CRM
# Date
# 2010-01-04    6.496294   NaN    9.700000    6.695000        NaN   18.705000
# 2010-01-05    6.507527   NaN    9.710000    6.734500        NaN   18.625000
# 2010-01-06    6.404016   NaN    9.570000    6.612500        NaN   18.592501
# 2010-01-07    6.392177   NaN    9.470000    6.500000        NaN   18.510000
# 2010-01-08    6.434675   NaN    9.430000    6.676000        NaN   18.537500
# ...                ...   ...         ...         ...        ...         ...
# 2023-07-07  190.679993  4.20  113.169998  129.779999  90.550003  209.589996
# 2023-07-10  188.610001  4.24  113.580002  127.129997  90.559998  212.809998
# 2023-07-11  188.080002  4.39  111.320000  128.779999  91.790001  221.169998
# 2023-07-12  189.770004  4.40  114.580002  130.800003  94.000000  227.279999
# ...

# %%
ff
# Out:
#               Adj Close                                                 \
#                     CMG         DPZ         MCD       PZZA        SBUX
# Date
# 2010-01-04    87.839996    7.174518   42.994110  10.300787    9.164432
# 2010-01-05    89.019997    7.240642   42.665390  10.401219    9.379128
# 2010-01-06    87.320000    7.447281   42.083282  10.409953    9.311540
# 2010-01-07    86.430000    7.744841   42.391445  10.427422    9.287686
# 2010-01-08    91.889999    7.744841   42.350365  10.431787    9.255880
# ...                 ...         ...         ...        ...         ...
# 2023-07-07  2077.459961  341.679993  292.100006  75.989998   96.050003
# 2023-07-10  2093.090088  347.410004  294.489990  77.690002   99.129997
# 2023-07-11  2053.280029  349.790009  294.739990  77.120003  100.089996
# 2023-07-12  2076.000000  388.589996  295.609985  77.110001  101.139999
# 2023-07-13  2048.860107  386.869995  295.220001  75.550003  101.599998
#
# ...

# %%
tech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3404 entries, 2010-01-04 to 2023-07-13
# Columns: 114 entries, ('Adj Close', 'AAPL') to ('Volume', 'ZG')
# dtypes: float64(102), int64(12)
# memory usage: 3.0 MB

# %%
tech.to_csv("TechStocks.csv")

# %%
tech.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',  'AMC'),
#             ('Adj Close',  'AMD'),
#             ('Adj Close', 'AMZN'),
#             ('Adj Close', 'BABA'),
#             ('Adj Close',  'CRM'),
#             ('Adj Close',   'EA'),
#             ('Adj Close',  'GME'),
#             ('Adj Close', 'GOOG'),
#             ('Adj Close', 'INTC'),
#             ...
#             (   'Volume', 'INTC'),
#             (   'Volume', 'META'),
#             (   'Volume', 'MSFT'),
#             (   'Volume', 'MTCH'),
#             (   'Volume', 'NVDA'),
#             (   'Volume', 'ORCL'),
#             (   'Volume', 'PYPL'),
#             (   'Volume', 'TSLA'),
#             (   'Volume', 'YELP'),
#             (   'Volume',   'ZG')],
#            length=114)

# %%
tclose = tech.loc[:,"Close"]

# %%
tclose
# Out:
#                   AAPL   AMC         AMD        AMZN       BABA         CRM  \
# Date
# 2010-01-04    7.643214   NaN    9.700000    6.695000        NaN   18.705000
# 2010-01-05    7.656429   NaN    9.710000    6.734500        NaN   18.625000
# 2010-01-06    7.534643   NaN    9.570000    6.612500        NaN   18.592501
# 2010-01-07    7.520714   NaN    9.470000    6.500000        NaN   18.510000
# 2010-01-08    7.570714   NaN    9.430000    6.676000        NaN   18.537500
# ...                ...   ...         ...         ...        ...         ...
# 2023-07-07  190.679993  4.20  113.169998  129.779999  90.550003  209.589996
# 2023-07-10  188.610001  4.24  113.580002  127.129997  90.559998  212.809998
# 2023-07-11  188.080002  4.39  111.320000  128.779999  91.790001  221.169998
# 2023-07-12  189.770004  4.40  114.580002  130.800003  94.000000  227.279999
# 2023-07-13  190.539993  4.44  115.919998  134.300003  96.610001  230.369995
#
# ...

# %%
tclose = tech.loc[:,"Close"].copy()

# %%
tclose
# Out:
#                   AAPL   AMC         AMD        AMZN       BABA         CRM  \
# Date
# 2010-01-04    7.643214   NaN    9.700000    6.695000        NaN   18.705000
# 2010-01-05    7.656429   NaN    9.710000    6.734500        NaN   18.625000
# 2010-01-06    7.534643   NaN    9.570000    6.612500        NaN   18.592501
# 2010-01-07    7.520714   NaN    9.470000    6.500000        NaN   18.510000
# 2010-01-08    7.570714   NaN    9.430000    6.676000        NaN   18.537500
# ...                ...   ...         ...         ...        ...         ...
# 2023-07-07  190.679993  4.20  113.169998  129.779999  90.550003  209.589996
# 2023-07-10  188.610001  4.24  113.580002  127.129997  90.559998  212.809998
# 2023-07-11  188.080002  4.39  111.320000  128.779999  91.790001  221.169998
# 2023-07-12  189.770004  4.40  114.580002  130.800003  94.000000  227.279999
# 2023-07-13  190.539993  4.44  115.919998  134.300003  96.610001  230.369995
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# /tmp/ipykernel_29843/715908909.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
tclose.plot(figsize=[15,8], fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
tclose.iloc[0]
# Out:
# AAPL     7.643214
# AMC           NaN
# AMD      9.700000
# AMZN     6.695000
# BABA          NaN
# CRM     18.705000
# EA      18.150000
# GME      5.725000
# GOOG    15.610239
# INTC    20.879999
# META          NaN
# MSFT    30.950001
# MTCH     5.856653
# NVDA     4.622500
# ORCL    24.850000
# PYPL          NaN
# TSLA          NaN
# YELP          NaN
# ZG            NaN
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
# ...                ...        ...         ...         ...        ...
# 2023-07-07  190.679993   4.200000  113.169998  129.779999  90.550003
# 2023-07-10  188.610001   4.240000  113.580002  127.129997  90.559998
# 2023-07-11  188.080002   4.390000  111.320000  128.779999  91.790001
# 2023-07-12  189.770004   4.400000  114.580002  130.800003  94.000000
# 2023-07-13  190.539993   4.440000  115.919998  134.300003  96.610001
#
#                    CRM          EA        GME        GOOG       INTC  \
# Date
# ...

# %%
tclose.iloc[0]
# Out:
# AAPL    31.500000
# AMC     30.610001
# AMD      2.470000
# AMZN    21.802000
# BABA    80.230003
# CRM     69.160004
# EA      68.010002
# GME     11.080000
# GOOG    26.143000
# INTC    30.040001
# META    87.550003
# MSFT    44.389999
# MTCH    22.781267
# NVDA     5.042500
# ORCL    40.150002
# PYPL    36.709999
# TSLA    18.648001
# YELP    37.490002
# ZG      26.526348
# Name: 2015-07-06 00:00:00, dtype: float64

# %%
normclose = close.div(close.iloc[0]).mul(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 normclose = close.div(close.iloc[0]).mul(100)
#
# NameError: name 'close' is not defined

# %%
normtclose = tclose.div(tclose.iloc[0]).mul(100)

# %%
normtclose
# Out:
#                   AAPL         AMC          AMD        AMZN        BABA  \
# Date
# 2015-07-06  100.000000  100.000000   100.000000  100.000000  100.000000
# 2015-07-07   99.753970  100.784057    84.615380  100.155951   99.239685
# 2015-07-08   97.277778   99.542629    81.376517   98.546008   97.145705
# 2015-07-09   95.293651  100.065333    80.161943   99.621592   98.516761
# 2015-07-10   97.841269  102.417510    79.352227  101.713149  100.087249
# ...                ...         ...          ...         ...         ...
# 2023-07-07  605.333310   13.721005  4581.781249  595.266482  112.863018
# 2023-07-10  598.761907   13.851681  4598.380588  583.111627  112.875475
# 2023-07-11  597.079371   14.341718  4506.882527  590.679747  114.408572
# 2023-07-12  602.444458   14.374387  4638.866417  599.944972  117.163151
# 2023-07-13  604.888868   14.505064  4693.117280  615.998545  120.416299
#
#                    CRM          EA         GME        GOOG        INTC  \
# Date
# ...

# %%
tclose.plot(figsize=[15,8], fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret = tclose.pct_change().dropna()

# %%
ret
# Out:
#                 AAPL       AMC       AMD      AMZN      BABA       CRM  \
# Date
# 2015-07-07 -0.002460  0.007841 -0.153846  0.001560 -0.007603  0.015905
# 2015-07-08 -0.024823 -0.012318 -0.038277 -0.016074 -0.021100 -0.012383
# 2015-07-09 -0.020397  0.005251 -0.014925  0.010915  0.014113  0.008214
# 2015-07-10  0.026734  0.023506 -0.010101  0.020995  0.015941  0.016867
# 2015-07-13  0.019306  0.015630  0.000000  0.027192  0.019427 -0.001265
# ...              ...       ...       ...       ...       ...       ...
# 2023-07-07 -0.005891 -0.020979 -0.002732  0.011063  0.080033 -0.002617
# 2023-07-10 -0.010856  0.009524  0.003623 -0.020419  0.000110  0.015363
# 2023-07-11 -0.002810  0.035377 -0.019898  0.012979  0.013582  0.039284
# 2023-07-12  0.008986  0.002278  0.029285  0.015686  0.024077  0.027626
# 2023-07-13  0.004057  0.009091  0.011695  0.026758  0.027766  0.013596
#
#                   EA       GME      GOOG      INTC      META      MSFT  \
# Date
# ...

# %%
ret.head()
# Out:
#                 AAPL       AMC       AMD      AMZN      BABA       CRM  \
# Date
mean", "std"]]
summary
# Out:
#           mean       std
# AAPL  0.001069  0.018811
# AMC   0.001784  0.092327
# AMD   0.002633  0.038576
# AMZN  0.001121  0.021003
# BABA  0.000454  0.027206
# CRM   0.000842  0.022237
# EA    0.000525  0.018971
# GME   0.002745  0.074379
# GOOG  0.000943  0.018361
# INTC  0.000286  0.021249
# META  0.000936  0.024467
# MSFT  0.001170  0.017743
# MTCH  0.000839  0.030821
# NVDA  0.002721  0.031287
# ORCL  0.000672  0.016838
# PYPL  0.000634  0.024324
# TSLA  0.002006  0.036566
# YELP  0.000532  0.032185
# ZG    0.000940  0.034370

# %%
# Multiplying by the number of business days in a year
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.269339  0.298615
# AMC   0.449645  1.465651
# AMD   0.663527  0.612375
# AMZN  0.282460  0.333405
# BABA  0.114461  0.431882
# CRM   0.212194  0.353000
# EA    0.132374  0.301151
# GME   0.691809  1.180735
# GOOG  0.237514  0.291468
# INTC  0.072181  0.337311
# META  0.235873  0.388399
# MSFT  0.294833  0.281660
# MTCH  0.211541  0.489264
# NVDA  0.685788  0.496669
# ORCL  0.169360  0.267297
# PYPL  0.159879  0.386130
# TSLA  0.505509  0.580463
# YELP  0.134049  0.510929
# ZG    0.236866  0.545602

# %%
summary.plot.scatter(x="std", y="mean", figsize=(12,8), s=50, fontsize=15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i,"std"]+0.005, summary.loc[i,"mean"]+0.005), size=12)
plt.xlabel("Annual risk(std)", fontsize = 15)
plt.ylabel("Annual return", fontsize = 15)
plt.title("Risk/Return", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Risk/Return')

# %% [markdown]
# ## Correlation and Covariance

# %%
import seaborn as sns

# %%
ret.cov()
ret.corr()
# Out:
#           AAPL       AMC       AMD      AMZN      BABA       CRM        EA  \
# AAPL  1.000000  0.118688  0.439011  0.599207  0.382855  0.552876  0.407703
# AMC   0.118688  1.000000  0.077088  0.097288  0.104399  0.129797  0.048199
# AMD   0.439011  0.077088  1.000000  0.414964  0.301811  0.411022  0.292706
# AMZN  0.599207  0.097288  0.414964  1.000000  0.393545  0.583556  0.418436
# BABA  0.382855  0.104399  0.301811  0.393545  1.000000  0.369612  0.270875
# CRM   0.552876  0.129797  0.411022  0.583556  0.369612  1.000000  0.406100
# EA    0.407703  0.048199  0.292706  0.418436  0.270875  0.406100  1.000000
# GME   0.160116  0.565472  0.117130  0.122046  0.125773  0.120456  0.060073
# GOOG  0.639955  0.103594  0.392829  0.664357  0.392105  0.578065  0.404611
# INTC  0.552983  0.095154  0.386445  0.434590  0.356275  0.451390  0.372144
# META  0.555738  0.114686  0.355026  0.610782  0.387069  0.531439  0.350192
# ...

# %%
ret.cov()
# Out:
#           AAPL       AMC       AMD      AMZN      BABA       CRM        EA  \
# AAPL  0.000354  0.000206  0.000319  0.000237  0.000196  0.000231  0.000145
# AMC   0.000206  0.008524  0.000275  0.000189  0.000262  0.000266  0.000084
# AMD   0.000319  0.000275  0.001488  0.000336  0.000317  0.000353  0.000214
# AMZN  0.000237  0.000189  0.000336  0.000441  0.000225  0.000273  0.000167
# BABA  0.000196  0.000262  0.000317  0.000225  0.000740  0.000224  0.000140
# CRM   0.000231  0.000266  0.000353  0.000273  0.000224  0.000494  0.000171
# EA    0.000145  0.000084  0.000214  0.000167  0.000140  0.000171  0.000360
# GME   0.000224  0.003883  0.000336  0.000191  0.000255  0.000199  0.000085
# GOOG  0.000221  0.000176  0.000278  0.000256  0.000196  0.000236  0.000141
# INTC  0.000221  0.000187  0.000317  0.000194  0.000206  0.000213  0.000150
# META  0.000256  0.000259  0.000335  0.000314  0.000258  0.000289  0.000163
# ...

# %%
plt.figure(figsize=(30,20))
sns.set(font_scale=1.5)
sns.heatmap(ret.corr(),cmap="Reds", annot=True, annot_kws={"size":15}, vmax=0.6)
plt.show()

# %%
MSFT = yf.download("MSFT", start="2010-01-01", end="2023-07-14")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
msft = MSFT.Close.to_frame()

# %%
msft.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
msft["SMA50"]=msft.rolling(window=50,min_periods=50).mean()

# %%
msft["SMA200"]=msft.Close.rolling(window=200,min_periods=200).mean()

# %%
msft.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
msft
# Out:
#                  Close       SMA50    SMA200
# Date
# 2010-01-04   30.950001         NaN       NaN
# 2010-01-05   30.959999         NaN       NaN
# 2010-01-06   30.770000         NaN       NaN
# 2010-01-07   30.450001         NaN       NaN
# 2010-01-08   30.660000         NaN       NaN
# ...                ...         ...       ...
# 2023-07-07  337.220001  324.184199  269.3280
# 2023-07-10  331.829987  324.913398  269.7749
# 2023-07-11  332.470001  325.466199  270.2425
# 2023-07-12  337.200012  326.064999  270.7236
# 2023-07-13  342.660004  326.806999  271.2473
#
# [3404 rows x 3 columns]

# %%
# Backtesting SMA Crossover Strategy

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S,SMA_L,start,end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None
        self.get_data()
    
    def get_data(self):
        df=yf.download(self.symbol,start=self.start,end=self.end)
        data=df.Close.to_frame()
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2 = data
        
        return data
    
    def test_result(self):
        data = self.data2.copy().dropna()
        data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"]=data["returns"]*data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsbuyhold"] = data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"] = data["strategy"].cumsum().apply(np.exp)
        perf = data["returnsstrategy"].iloc[-1]
        outperf = perf - data["returnsbuyhold"].iloc[-1]
        self.results = data
        
        ret=np.exp(data["strategy"].sum())
        std=data["strategy"].std()*np.sqrt(252)

        #return ret, std
        return round(perf,6), round(outperf,6)
    
    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title = "{} | SMA_S={} | SMA_L={}".format(self.symbol, self.SMA_S, self.SMA_L)
            self.results[["returnsbuyhold","returnsstrategy"]].plot(title=title, figsize=(12,8))

# %%
#Using a 50 and 100 day SMA for AMZN
AMZNtester = SMABacktester("AMZN", 50, 100, "2000-01-01", "2023-07-14")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
AMZNtester.test_result()
# Out:
# (17.884235, -37.425935)

# %%
AMZNtester.plot_results()

# %%
AAPLtester = SMABacktester("AAPL", 50, 100, "2000-01-01", "2023-07-14")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
AAPLtester.test_result()
# Out:
# (13.35739, -230.012329)

# %%
AAPLtester.plot_results()

# %%
NVDAtester = SMABacktester("NVDA", 50, 100, "2000-01-01", "2023-07-14")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
NVDAtester.test_result()
# Out:
# (1303.090315, 1095.870039)

# %%
NVDAtester.plot_results()

# %%
TSLAtester = SMABacktester("NVDA", 50, 100, "2000-01-01", "2023-07-14")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
TSLAtester.test_result()
# Out:
# (1303.090315, 1095.870039)

# %%
TSLAtester.plot_results()
